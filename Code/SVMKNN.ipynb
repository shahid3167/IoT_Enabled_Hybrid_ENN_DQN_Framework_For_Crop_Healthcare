# %%
# === 1. Import Required Libraries ===
import pandas as pd
import numpy as np
import warnings

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, roc_auc_score
)
from imblearn.over_sampling import SMOTE
from sklearn.svm import SVC

# Suppress warnings from precision_score when a model makes no positive predictions (common in early epochs)
warnings.filterwarnings('ignore', category=UserWarning)

# === 2. Load Dataset ===
# Provide your path here
try:
    combined_dataset = pd.read_csv("/Users/administrator/Desktop/All desktop-data/Prof-Irshad Papers/2025-Papers/10K-Paper/Crop-IoT-Paper/IoT-Journal-Submission/Manuscript-R2/Code-For-Github/Combined_Data.csv")
except FileNotFoundError:
    print("Error: CSV file not found. Using a dummy dataframe for demonstration.")
    data = np.random.rand(5000, 9)
    columns = ['N', 'P', 'K', 'Temp', 'H', 'pH', 'R', 'WL', 'CH']
    combined_dataset = pd.DataFrame(data, columns=columns)
    combined_dataset['CH'] = np.random.randint(0, 2, 5000)

# === 3. Prepare Features and Labels ===
features = ['N', 'P', 'K', 'Temp', 'H', 'pH', 'R', 'WL']
X = combined_dataset[features]
y = combined_dataset['CH']

# === 4. Train-Test Split ===
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

# === 5. Scale Features ===
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# === 6. Balance the TRAINING Dataset with SMOTE ===
print("Balancing the training data with SMOTE...")
sm = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = sm.fit_resample(X_train_scaled, y_train)
print("Balancing complete.")

# === 7. Run Simulation for SVM Model ===
EPOCHS = 163
acc_list, prec_list, rec_list, f1_list, auc_list = [], [], [], [], []

# Get the total number of samples in the balanced training data
n_samples = len(X_train_resampled)
print(f"\nStarting SVM simulation for {EPOCHS} epochs...")
print("-" * 60)

for epoch in range(1, EPOCHS + 1):
    # Calculate the size of the data subset for the current epoch
    subset_size = int(n_samples * (epoch / EPOCHS))
    subset_size = max(2, subset_size) # Ensure at least 2 samples for fitting
    
    # Take a subset of the training data
    X_subset = X_train_resampled[:subset_size]
    y_subset = y_train_resampled[:subset_size]
    
    # Skip epoch if the small subset doesn't contain both classes
    if len(np.unique(y_subset)) < 2:
        print(f"Epoch {epoch:03d}/{EPOCHS}: Skipped (not enough class diversity in small data subset)")
        # Append last known values or defaults to keep list lengths consistent
        acc_list.append(acc_list[-1] if acc_list else 0.5)
        prec_list.append(prec_list[-1] if prec_list else 0)
        rec_list.append(rec_list[-1] if rec_list else 0)
        f1_list.append(f1_list[-1] if f1_list else 0)
        auc_list.append(auc_list[-1] if auc_list else 0.5)
        continue

    # --- Define and Train the SVM Model on the current subset ---
    svm_model = SVC(kernel='linear', probability=True, C=0.5, random_state=42)
    svm_model.fit(X_subset, y_subset)

    # --- Evaluate on the FULL, UNSEEN test set ---
    svm_probs = svm_model.predict_proba(X_test_scaled)[:, 1]
    y_pred = (svm_probs >= 0.5).astype(int)

    # --- Calculate and Store Metrics ---
    acc = accuracy_score(y_test, y_pred)
    prec = precision_score(y_test, y_pred, zero_division=0)
    rec = recall_score(y_test, y_pred, zero_division=0)
    f1 = f1_score(y_test, y_pred, zero_division=0)
    auc = roc_auc_score(y_test, svm_probs) # Use probabilities for AUC

    # Store metrics
    acc_list.append(acc)
    prec_list.append(prec)
    rec_list.append(rec)
    f1_list.append(f1)
    auc_list.append(auc)

    # Print performance for the current epoch
    print(f"Epoch {epoch:03d}/{EPOCHS} -> "
          f"Accuracy: {acc*100:.2f}%, Precision: {prec*100:.2f}%, "
          f"Recall: {rec*100:.2f}%, F1: {f1*100:.2f}%, AUC: {auc*100:.2f}%")


# === 8. Store History in a DataFrame for Later Use ===
metrics_df = pd.DataFrame({
    'Epoch': range(1, EPOCHS + 1),
    'Accuracy': acc_list,
    'Precision': prec_list,
    'Recall': rec_list,
    'F1Score': f1_list,
    'AUC': auc_list
})

print("\n" + "="*40)
print("Simulation Complete.")
print(f"Final performance at Epoch {EPOCHS}:")
# Display the last row of the DataFrame for the final results
print(metrics_df.iloc[-1].to_string())
print("="*40)
# Out:
# Balancing the training data with SMOTE...
# Balancing complete.
#
# Starting SVM simulation for 163 epochs...
# ------------------------------------------------------------
# Epoch 001/163: Skipped (not enough class diversity in small data subset)
# Epoch 002/163: Skipped (not enough class diversity in small data subset)
# Epoch 003/163: Skipped (not enough class diversity in small data subset)
# Epoch 004/163: Skipped (not enough class diversity in small data subset)
# Epoch 005/163: Skipped (not enough class diversity in small data subset)
# Epoch 006/163: Skipped (not enough class diversity in small data subset)
# Epoch 007/163: Skipped (not enough class diversity in small data subset)
# Epoch 008/163: Skipped (not enough class diversity in small data subset)
# Epoch 009/163: Skipped (not enough class diversity in small data subset)
# Epoch 010/163: Skipped (not enough class diversity in small data subset)
# Epoch 011/163: Skipped (not enough class diversity in small data subset)
# Epoch 012/163: Skipped (not enough class diversity in small data subset)
# Epoch 013/163: Skipped (not enough class diversity in small data subset)
# Epoch 014/163: Skipped (not enough class diversity in small data subset)
# Epoch 015/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 78.88%
# Epoch 016/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 76.03%
# Epoch 017/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 80.02%
# Epoch 018/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 94.98%
# Epoch 019/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 25.23%
# Epoch 020/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 79.79%
# Epoch 021/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 3.08%
# Epoch 022/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 94.18%
# Epoch 023/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 92.47%
# Epoch 024/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 82.88%
# Epoch 025/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 84.70%
# Epoch 026/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 90.07%
# Epoch 027/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 86.07%
# Epoch 028/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 85.05%
# Epoch 029/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 84.70%
# Epoch 030/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 81.62%
# Epoch 031/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 84.59%
# Epoch 032/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 85.84%
# Epoch 033/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 81.51%
# Epoch 034/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 88.13%
# Epoch 035/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 62.56%
# Epoch 036/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 84.47%
# Epoch 037/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 83.45%
# Epoch 038/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 84.70%
# Epoch 039/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 82.99%
# Epoch 040/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 83.90%
# Epoch 041/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 94.41%
# Epoch 042/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 81.51%
# Epoch 043/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 82.88%
# Epoch 044/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 84.25%
# Epoch 045/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 84.02%
# Epoch 046/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 80.37%
# Epoch 047/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 90.30%
# Epoch 048/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 81.51%
# Epoch 049/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 82.19%
# Epoch 050/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 82.76%
# Epoch 051/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 83.68%
# Epoch 052/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 81.96%
# Epoch 053/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 80.37%
# Epoch 054/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 81.62%
# Epoch 055/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 81.96%
# Epoch 056/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 82.42%
# Epoch 057/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 81.85%
# Epoch 058/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 85.62%
# Epoch 059/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 93.04%
# Epoch 060/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 84.02%
# Epoch 061/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 89.16%
# Epoch 062/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 87.79%
# Epoch 063/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 92.12%
# Epoch 064/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 96.69%
# Epoch 065/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 97.83%
# Epoch 066/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 97.37%
# Epoch 067/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 96.80%
# Epoch 068/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 99.09%
# Epoch 069/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 95.09%
# Epoch 070/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 98.40%
# Epoch 071/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 82.19%
# Epoch 072/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 94.29%
# Epoch 073/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 98.63%
# Epoch 074/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 96.35%
# Epoch 075/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 90.64%
# Epoch 076/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 93.26%
# Epoch 077/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 96.00%
# Epoch 078/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 96.58%
# Epoch 079/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 93.84%
# Epoch 080/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 95.66%
# Epoch 081/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 96.46%
# Epoch 082/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 98.29%
# Epoch 083/163 -> Accuracy: 99.55%, Precision: 0.00%, Recall: 0.00%, F1: 0.00%, AUC: 91.21%
# Epoch 084/163 -> Accuracy: 99.55%, Precision: 50.00%, Recall: 50.00%, F1: 50.00%, AUC: 86.42%
# Epoch 085/163 -> Accuracy: 99.09%, Precision: 25.00%, Recall: 50.00%, F1: 33.33%, AUC: 86.07%
# Epoch 086/163 -> Accuracy: 98.86%, Precision: 20.00%, Recall: 50.00%, F1: 28.57%, AUC: 84.02%
# Epoch 087/163 -> Accuracy: 98.18%, Precision: 12.50%, Recall: 50.00%, F1: 20.00%, AUC: 78.31%
# Epoch 088/163 -> Accuracy: 97.50%, Precision: 9.09%, Recall: 50.00%, F1: 15.38%, AUC: 77.74%
# Epoch 089/163 -> Accuracy: 97.50%, Precision: 9.09%, Recall: 50.00%, F1: 15.38%, AUC: 77.85%
# Epoch 090/163 -> Accuracy: 97.50%, Precision: 9.09%, Recall: 50.00%, F1: 15.38%, AUC: 78.08%
# Epoch 091/163 -> Accuracy: 97.05%, Precision: 7.69%, Recall: 50.00%, F1: 13.33%, AUC: 80.02%
# Epoch 092/163 -> Accuracy: 96.82%, Precision: 7.14%, Recall: 50.00%, F1: 12.50%, AUC: 81.28%
# Epoch 093/163 -> Accuracy: 96.82%, Precision: 7.14%, Recall: 50.00%, F1: 12.50%, AUC: 81.85%
# Epoch 094/163 -> Accuracy: 96.82%, Precision: 7.14%, Recall: 50.00%, F1: 12.50%, AUC: 81.62%
# Epoch 095/163 -> Accuracy: 96.82%, Precision: 7.14%, Recall: 50.00%, F1: 12.50%, AUC: 81.85%
# Epoch 096/163 -> Accuracy: 96.82%, Precision: 7.14%, Recall: 50.00%, F1: 12.50%, AUC: 81.96%
# Epoch 097/163 -> Accuracy: 96.82%, Precision: 7.14%, Recall: 50.00%, F1: 12.50%, AUC: 81.96%
# Epoch 143/163 -> Accuracy: 92.50%, Precision: 3.03%, Recall: 50.00%, F1: 5.71%, AUC: 92.35%
# Epoch 144/163 -> Accuracy: 92.27%, Precision: 2.94%, Recall: 50.00%, F1: 5.56%, AUC: 92.47%
# Epoch 145/163 -> Accuracy: 92.05%, Precision: 2.86%, Recall: 50.00%, F1: 5.41%, AUC: 92.47%
# Epoch 146/163 -> Accuracy: 92.05%, Precision: 2.86%, Recall: 50.00%, F1: 5.41%, AUC: 92.58%
# Epoch 147/163 -> Accuracy: 92.05%, Precision: 2.86%, Recall: 50.00%, F1: 5.41%, AUC: 92.58%
# Epoch 148/163 -> Accuracy: 91.59%, Precision: 2.70%, Recall: 50.00%, F1: 5.13%, AUC: 92.69%
# Epoch 149/163 -> Accuracy: 91.82%, Precision: 2.78%, Recall: 50.00%, F1: 5.26%, AUC: 92.92%
# Epoch 150/163 -> Accuracy: 91.59%, Precision: 2.70%, Recall: 50.00%, F1: 5.13%, AUC: 92.92%
# Epoch 151/163 -> Accuracy: 91.82%, Precision: 2.78%, Recall: 50.00%, F1: 5.26%, AUC: 92.92%
# Epoch 152/163 -> Accuracy: 91.59%, Precision: 2.70%, Recall: 50.00%, F1: 5.13%, AUC: 92.92%
# Epoch 153/163 -> Accuracy: 91.59%, Precision: 2.70%, Recall: 50.00%, F1: 5.13%, AUC: 92.92%
# Epoch 154/163 -> Accuracy: 91.82%, Precision: 2.78%, Recall: 50.00%, F1: 5.26%, AUC: 92.92%
# Epoch 155/163 -> Accuracy: 91.36%, Precision: 2.63%, Recall: 50.00%, F1: 5.00%, AUC: 92.92%
# Epoch 156/163 -> Accuracy: 90.91%, Precision: 2.50%, Recall: 50.00%, F1: 4.76%, AUC: 93.15%
# Epoch 157/163 -> Accuracy: 90.91%, Precision: 2.50%, Recall: 50.00%, F1: 4.76%, AUC: 93.15%
# Epoch 158/163 -> Accuracy: 90.91%, Precision: 2.50%, Recall: 50.00%, F1: 4.76%, AUC: 93.15%
# Epoch 159/163 -> Accuracy: 91.14%, Precision: 2.56%, Recall: 50.00%, F1: 4.88%, AUC: 93.15%
# Epoch 160/163 -> Accuracy: 90.91%, Precision: 2.50%, Recall: 50.00%, F1: 4.76%, AUC: 93.26%
# Epoch 161/163 -> Accuracy: 90.68%, Precision: 2.44%, Recall: 50.00%, F1: 4.65%, AUC: 93.38%
# Epoch 162/163 -> Accuracy: 90.45%, Precision: 2.38%, Recall: 50.00%, F1: 4.55%, AUC: 93.38%
# Epoch 163/163 -> Accuracy: 90.45%, Precision: 2.38%, Recall: 50.00%, F1: 4.55%, AUC: 93.38%
#
# ========================================
# Simulation Complete.
# Final performance at Epoch 163:
# Epoch        163.000000
# Accuracy       0.904545
# Precision      0.023810
# Recall         0.500000
# F1Score        0.045455
# AUC            0.933790
# ========================================
